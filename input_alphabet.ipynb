# %%
A = {'A' : 'エー', 'B' : 'ビー', 'C' : 'シー', 'D' : 'ディー', 'E' : 'イー', 'F' : 'エフ', 'G' : 'ジー',
     'H' : 'エイチ', 'I' : 'アイ', 'J' : 'ジェイ', 'K' : 'ケイ', 'L' : 'エル', 'M' : 'エム', 'N' : 'エヌ',
     'O' : 'オー', 'P' : 'ピー', 'Q' : 'キュー', 'R' : 'アール', 'S' : 'エス', 'T' : 'ティー', 'U' : 'ユー',
     'V' : 'ヴィー', 'W' : 'ダブリュー', 'X' : 'エックス', 'Y' : 'ワイ', 'Z' : 'ズィー'}

a = {'a' : 'エー', 'b' : 'ビー', 'c' : 'シー', 'd' : 'ディー', 'e' : 'イー', 'f' : 'エフ', 'g' : 'ジー',
     'h' : 'エイチ', 'i' : 'アイ', 'j' : 'ジェイ', 'k' : 'ケイ', 'l' : 'エル', 'm' : 'エム', 'n' : 'エヌ',
     'o' : 'オー', 'p' : 'ピー', 'q' : 'キュー', 'r' : 'アール', 's' : 'エス', 't' : 'ティー', 'u' : 'ユー',
     'v' : 'ヴィー', 'w' : 'ダブリュー', 'x' : 'エックス', 'y' : 'ワイ', 'z' : 'ズィー'}


print('大文字はshiftを押しながら入力します')
    
large = input('キーボードでアルファベット大文字を入力してください')

if large == 'A':
    key_A1 = '1'
    value1 = A.get('A')
    print('{}は{}番目の文字で{}です'.format(large, key_A1, value1))

elif large == 'B':
    key_A2 = '2'
    value2 = A.get('B')
    print('{}は{}番目の文字で{}です'.format(large, key_A2, value2))

elif large == 'C':
    key_A3 = '3'
    value3 = A.get('C')
    print('{}は{}番目の文字で{}です'.format(large, key_A3, value3))

elif large == 'D':
    key_A4 = '4'
    value4 = A.get('D')
    print('{}は{}番目の文字で{}です'.format(large, key_A4, value4))

elif large == 'E':
    key_A5 = '5'
    value5 = A.get('E')
    print('{}は{}番目の文字で{}です'.format(large, key_A5, value5))

elif large == 'F':
    key_A6 = '6'
    value6 = A.get('F')
    print('{}は{}番目の文字で{}です'.format(large, key_A6, value6))

elif large == 'G':
    key_A7 = '7'
    value7 = A.get('G')
    print('{}は{}番目の文字で{}です'.format(large, key_A7, value7))

elif large == 'H':
    key_A8 = '8'
    value8 = A.get('H')
    print('{}は{}番目の文字で{}です'.format(large, key_A8, value8))

elif large == 'I':
    key_A9 = '9'
    value9 = A.get('I')
    print('{}は{}番目の文字で{}です'.format(large, key_A9, value9))

elif large == 'J':
    key_A10 = '10'
    value10 = A.get('J')
    print('{}は{}番目の文字で{}です'.format(large, key_A10, value10))

elif large == 'K':
    key_A11 = '11'
    value11 = A.get('K')
    print('{}は{}番目の文字で{}です'.format(large, key_A11, value11))

elif large == 'L':
    key_A12 = '12'
    value12 = A.get('L')
    print('{}は{}番目の文字で{}です'.format(large, key_A12, value12))

elif large == 'M':
    key_A13 = '13'
    value13 = A.get('M')
    print('{}は{}番目の文字で{}です'.format(large, key_A13, value13))

elif large == 'N':
    key_A14 = '14'
    value14 = A.get('N')
    print('{}は{}番目の文字で{}です'.format(large, key_A14, value14))

elif large == 'O':
    key_A15 = '15'
    value15 = A.get('O')
    print('{}は{}番目の文字で{}です'.format(large, key_A15, value15))

elif large == 'P':
    key_A16 = '16'
    value16 = A.get('P')
    print('{}は{}番目の文字で{}です'.format(large, key_A16, value16))

elif large == 'Q':
    key_A17 = '17'
    value17 = A.get('Q')
    print('{}は{}番目の文字で{}です'.format(large, key_A17, value17))

elif large == 'R':
    key_A18 = '18'
    value18 = A.get('R')
    print('{}は{}番目の文字で{}です'.format(large, key_A18, value18))

elif large == 'S':
    key_A19 = '19'
    value19 = A.get('S')
    print('{}は{}番目の文字で{}です'.format(large, key_A19, value19))

elif large == 'T':
    key_A20 = '20'
    value20 = A.get('T')
    print('{}は{}番目の文字で{}です'.format(large, key_A20, value20))

elif large == 'U':
    key_A21 = '21'
    value21 = A.get('U')
    print('{}は{}番目の文字で{}です'.format(large, key_A21, value21))

elif large == 'V':
    key_A22 = '22'
    value22 = A.get('V')
    print('{}は{}番目の文字で{}です'.format(large, key_A22, value22))

elif large == 'W':
    key_A23 = '23'
    value23 = A.get('W')
    print('{}は{}番目の文字で{}です'.format(large, key_A23, value23))

elif large == 'X':
    key_A24 = '24'
    value24 = A.get('X')
    print('{}は{}番目の文字で{}です'.format(large, key_A24, value24))

elif large == 'Y':
    key_A25 = '25'
    value25 = A.get('Y')
    print('{}は{}番目の文字で{}です'.format(large, key_A25, value25))

elif large == 'Z':
    key_A26 = '26'
    value26 = A.get('Z')
    print('{}は{}番目の文字で{}です'.format(large, key_A26, value26))

print('小文字はshiftを押さずにそのまま入力します')

small = input('キーボードでアルファベット小文字を入力してください')

if small == 'a':
    key_a1 = '1'
    value1 = a.get('a')
    print('{}は{}番目の文字で{}です'.format(small, key_a1, value1))

elif small == 'b':
    key_a2 = '2'
    value2 = a.get('b')
    print('{}は{}番目の文字で{}です'.format(small, key_a2, value2))

elif small == 'c':
    key_a3 = '3'
    value3 = a.get('c')
    print('{}は{}番目の文字で{}です'.format(small, key_a3, value3))

elif small == 'd':
    key_a4 = '4'
    value4 = a.get('d')
    print('{}は{}番目の文字で{}です'.format(small, key_a4, value4))

elif small == 'e':
    key_a5 = '5'
    value5 = a.get('e')
    print('{}は{}番目の文字で{}です'.format(small, key_a5, value5))

elif small == 'f':
    key_a6 = '6'
    value6 = a.get('f')
    print('{}は{}番目の文字で{}です'.format(small, key_a6, value6))

elif small == 'g':
    key_a7 = '7'
    value7 = a.get('g')
    print('{}は{}番目の文字で{}です'.format(small, key_a7, value7))

elif small == 'h':
    key_a8 = '8'
    value8 = a.get('h')
    print('{}は{}番目の文字で{}です'.format(small, key_a8, value8))

elif small == 'i':
    key_a9 = '9'
    value9 = a.get('i')
    print('{}は{}番目の文字で{}です'.format(small, key_a9, value9))

elif small == 'j':
    key_a10 = '10'
    value10 = a.get('j')
    print('{}は{}番目の文字で{}です'.format(small, key_a10, value10))

elif small == 'k':
    key_a11 = '11'
    value11 = a.get('k')
    print('{}は{}番目の文字で{}です'.format(small, key_a11, value11))

elif small == 'l':
    key_a12 = '12'
    value12 = a.get('l')
    print('{}は{}番目の文字で{}です'.format(small, key_a12, value12))

elif small == 'm':
    key_a13 = '13'
    value13 = a.get('m')
    print('{}は{}番目の文字で{}です'.format(small, key_a13, value13))

elif small == 'n':
    key_a14 = '14'
    value14 = a.get('n')
    print('{}は{}番目の文字で{}です'.format(small, key_a14, value14))

elif small == 'o':
    key_a15 = '15'
    value15 = a.get('o')
    print('{}は{}番目の文字で{}です'.format(small, key_a15, value15))

elif small == 'p':
    key_a16 = '16'
    value16 = a.get('p')
    print('{}は{}番目の文字で{}です'.format(small, key_a16, value16))

elif small == 'q':
    key_a17 = '17'
    value17 = a.get('q')
    print('{}は{}番目の文字で{}です'.format(small, key_a17, value17))

elif small == 'r':
    key_a18 = '18'
    value18 = a.get('r')
    print('{}は{}番目の文字で{}です'.format(small, key_a18, value18))

elif small == 's':
    key_a19 = '19'
    value19 = a.get('s')
    print('{}は{}番目の文字で{}です'.format(small, key_a19, value19))

elif small == 't':
    key_a20 = '20'
    value20 = a.get('t')
    print('{}は{}番目の文字で{}です'.format(small, key_a20, value20))

elif small == 'u':
    key_a21 = '21'
    value21 = a.get('u')
    print('{}は{}番目の文字で{}です'.format(small, key_a21, value21))

elif small == 'v':
    key_a22 = '22'
    value22 = a.get('v')
    print('{}は{}番目の文字で{}です'.format(small, key_a22, value22))

elif small == 'w':
    key_a23 = '23'
    value23 = a.get('w')
    print('{}は{}番目の文字で{}です'.format(small, key_a23, value23))

elif small == 'x':
    key_a24 = '24'
    value24 = a.get('x')
    print('{}は{}番目の文字で{}です'.format(small, key_a24, value24))

elif small == 'y':
    key_a25 = '25'
    value25 = a.get('y')
    print('{}は{}番目の文字で{}です'.format(small, key_a25, value25))

elif small == 'z':
    key_a26 = '26'
    value26 = a.get('z')
    print('{}は{}番目の文字で{}です'.format(small, key_a26, value26))
# Out:
# 大文字はshiftを押しながら入力します
# キーボードでアルファベット大文字を入力してくださいZ
# Zは26番目の文字でズィーです
# 小文字はshiftを押さずにそのまま入力します
# キーボードでアルファベット小文字を入力してくださいz
# zは26番目の文字でズィーです

# %%
h
